# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data file reading 

def collect_data (n, interaction): # n is the number of files

    files = [];
    raw_data = [];
    data = [];

    for i in range (0, n, 1):

        files.append (open ("data"+ str (i) + "-" + interaction + ".txt","r"));
        raw_data.append (files[i].readlines());

        arr = [];
        
        for line in raw_data[i]:

            
            dat = line.split();

            if (len (dat) == 0):
                break;
                
            arr.append (float (dat[0]));

        data.append (arr);

    return data;

# %%
# Statistics 

def stats (arr):

    # Mean

    mu = 0;
    
    for i in range (29, len(arr), 1):
        mu = mu + arr[i];
        
    mu = mu / (len (arr)-30);

    sigma = 0;
    
    for i in range (29, len(arr), 1):
        sigma = sigma + pow (arr[i] - mu, 2);

    sigma = np.sqrt(sigma / (len (arr)-30));

    return [mu, sigma]

# %%
# a = 25 data collection

n = 7;

data25 = collect_data (n, "25");

# a = 75 data collection

data75 = collect_data (n, "75");

# %%
# Means and standard deviations

mu25 = [];
sigma25 = [];

mu75 = [];
sigma75 = [];

for i in range (0, n, 1):
    
    mui25, sigmai25  = stats (data25[i]);
    mui75, sigmai75  = stats (data75[i]);

    mu25.append (mui25);
    sigma25.append (sigmai25);

    mu75.append (mui75);
    sigma75.append (sigmai75);

# %%
print (mu25)
# Out:
# [1.0129320123943664, 1.0159807619718306, 1.0121006995774646, 1.0135331130985914, 1.0138369128169014, 1.016019268873239, 1.0162831571830984]

# %%
print (sigma25)
# Out:
# [0.02535213027030631, 0.026346096161655546, 0.02360804211033019, 0.02543561112236786, 0.02416585872936902, 0.026357405079961135, 0.023032682723781707]

# %%
print (mu75)
# Out:
# [1.162711201126761, 1.0244143233802816, 1.0167848985915493, 1.0237387126760564, 46.17563145070422, 1.1924375535211265, 1.3782875225352114]

# %%
print (sigma75)
# Out:
# [0.13640253853001635, 0.02837727987552265, 0.023396339487685016, 0.026133785522922042, 1.346486279641925, 0.03043135103053204, 0.033611966105820075]

# %%
# time step array

dt_arr25 = [0.001, 0.005, 0.008, 0.01, 0.05, 0.08, 0.1];
dt_arr75 = [0.001, 0.005, 0.008, 0.01, 0.05, 0.06, 0.07];

# %%
fig, ax = plt.subplots(1,1,figsize=[6,6]);
ax.set_xlabel("$\Delta t$");
ax.set_ylabel("$k_{B}T - 1$");
ax.set_title("");
#ax.set_xlim([0, 4]);
#ax.set_ylim([-1, 2]);

ax.errorbar (dt_arr25, mu25, xerr = 0, yerr = sigma25, color = "black", label = "a = 25");
#ax.errorbar (dt_arr75, mu75, xerr = 0, yerr = sigma75, color = "darkgreen", label = "a = 75");
    
    
ax.grid();
ax.legend(loc = "upper right");
plt.show(fig);
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# /var/folders/7z/6sny2vy960992wnrq442m5nm0000gn/T/ipykernel_95778/1586246777.py:2: SyntaxWarning: invalid escape sequence '\D'
#   ax.set_xlabel("$\Delta t$");

# %%
fig1, ax1 = plt.subplots(1,1,figsize=[6,6]);
ax1.set_xlabel("$\Delta t$");
ax1.set_ylabel("$k_{B}T - 1$");
ax1.set_title("");
#ax.set_xlim([0, 4]);
#ax.set_ylim([-1, 2]);

ax1.errorbar (dt_arr75, mu75, xerr = 0, yerr = sigma75, color = "darkgreen", label = "a = 75");
    
    
ax1.grid();
ax1.legend(loc = "upper right");
plt.show(fig1);
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# /var/folders/7z/6sny2vy960992wnrq442m5nm0000gn/T/ipykernel_95778/3973342356.py:2: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta t$");
