# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
# Reading the data from a text file

ex_data = open ("exact.txt","r");
ex_pts = ex_data.readlines();

# Creating the x and y arrays

x_ex =[];
psi_ex =[];

for line in ex_pts:
    if (line.split()[0]!='x' or line.split()[1]!='psi_0'):
        x_ex.append(float(line.split()[0]));
        psi_ex.append(float(line.split()[1]));

# %%
# Reading the data from a text file
mc_data = open ("monte_carlo.txt","r");
mc_pts = mc_data.readlines();

# Creating the x and psi arrays

x_mc =[];
psi_mc =[];

for line in mc_pts:
    x_mc.append(float(line.split()[0]));
    psi_mc.append(float(line.split()[1]));

# %%
plt.scatter(x_mc, psi_mc)

# %%
#plt.hist(psi_mc, bins = 40, density = True, alpha = 0.8)

# %%
fig, ax = plt.subplots(1,1,figsize=[6,6]);
ax.set_xlabel('$x$');
ax.set_ylabel('$|\psi_0 (x)|^2$');
ax.set_title('QHO ground state');
#ax.set_xlim([0, 1]);
#ax.set_ylim([0, 4.5]);

ax.plot (x_ex, psi_ex, color = "darkblue",label = "Exact");
ax.scatter (x_mc, psi_mc, color = "darkred", marker = "o", label = "Monte Carlo");
    
ax.grid();
ax.legend(loc = "upper right");
plt.show(fig);
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/7z/6sny2vy960992wnrq442m5nm0000gn/T/ipykernel_38860/765204241.py:3: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_ylabel('$|\psi_0 (x)|^2$');

# %%
fig.savefig ("QHO_ground_state.jpg")
