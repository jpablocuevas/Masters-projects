# %% [markdown]
# # Electric field plot for a 1D Yee algorithm simulation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading the data from a text file
data_ptr_gauss = open ("Ez_plot_gaussian.txt","r");
data_gauss=data_ptr_gauss.readlines();

# Creating the x and y arrays
Ez_gauss=[];
t=[];

for line in data:
    
    if (line.split()[0]!='Ez' or line.split()[1]!='t'):
        Ez_gauss.append(float(line.split()[0]));
        t.append(float(line.split()[1]));

# %%
# Plotting the obtanied 
fig_gauss, ax_plot_gauss = plt.subplots(1,1);
ax_plot_gauss.set_xlabel("$t$");
ax_plot_gauss.set_ylabel("$Ez[50]$");
ax_plot_gauss.set_title("Gaussian source");
ax_plot_gauss.plot(t,Ez_gauss,color="forestgreen",label="Electric field pulse");
ax_plot_gauss.grid();
ax_plot_gauss.legend(loc="lower left");
#plt.show(fig_circ);

# %%
# Reading the data from a text file
data_ptr_sinu = open ("Ez_plot_sinusoidal.txt","r");
data_sinu=data_ptr_sinu.readlines();

# Creating the x and y arrays
Ez_sinu=[];
t=[];

for line in data_sinu:
    
    if (line.split()[0]!='Ez' or line.split()[1]!='t'):
        Ez_sinu.append(float(line.split()[0]));
        t.append(float(line.split()[1]));

# %%
# Plotting the obtanied 
fig_sinu, ax_plot_sinu = plt.subplots(1,1);
ax_plot_sinu.set_xlabel("$t$");
ax_plot_sinu.set_ylabel("$Ez[50]$");
ax_plot_sinu.set_title("Sinusoidal source");
ax_plot_sinu.plot(t,Ez_sinu,color="darkblue",label="Electric field pulse");
ax_plot_sinu.grid();
ax_plot_sinu.legend(loc="lower left");
#plt.show(fig_circ);
